# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
charts=pd.read_csv('Most-Recent-Cohorts-All-Data-Elements.csv')
charts.sample(5)
# Out:
#       UNITID    OPEID  OPEID6                         INSTNM          CITY  \
# 4275  377449  2334402   23344   Centura College-Newport News  Newport News
# 3785  237136   754400    7544      Appalachian Bible College    Mount Hope
# 6460  487320   363400    3634  Texas State Technical College          Waco
# 1472  162830  2269700   22697       Aveda Institute-Maryland       Bel Air
# 4586  419147  3066700   30667   Ailano School of Cosmetology      Brockton
#
#      STABBR         ZIP                                       ACCREDAGENCY  \
# 4275     VA       23608  Accrediting Commission of Career Schools and C...
# 3785     WV  25880-9557           Association for Bibical Higher Educaiton
# 6460     TX       76705  Southern Association of Colleges and Schools C...
# 1472     MD  21014-3639  National Accrediting Commission of Career Arts...
# 4586     MA  02301-5734                                                NaN
#
#                       INSTURL  \
# 4275   www.centuracollege.edu
# 3785          https://abc.edu
# 6460             www.tstc.edu
# 1472     avedainstitutemd.edu
# 4586  www.theailanoschool.com
#
#                                                  NPCURL  ...  \
# 4275  www.centuracollege.edu/Your_Rights/price_calc....  ...
# 3785  https://abc.edu/undergraduate/costs-and-aid/fi...  ...
# 6460  www.collegeforalltexans.com/apps/CollegeMoney/...  ...
# 1472                               avedainstitutemd.edu  ...
# 4586                               theailanoschool.com/  ...
#
#       IND_WDRAW_4YR_TRANS_YR3_RT  IND_WDRAW_2YR_TRANS_YR3_RT  \
# 4275           PrivacySuppressed                 0.069808028
# 3785           PrivacySuppressed           PrivacySuppressed
# 6460                 0.020618557                 0.072707542
# 1472           PrivacySuppressed           PrivacySuppressed
# 4586           PrivacySuppressed           PrivacySuppressed
#
#       IND_ENRL_ORIG_YR3_RT  IND_ENRL_4YR_TRANS_YR3_RT  \
# 4275     PrivacySuppressed          PrivacySuppressed
# 3785     PrivacySuppressed          PrivacySuppressed
# 6460           0.035268584                0.025501899
# 1472     PrivacySuppressed          PrivacySuppressed
# 4586     PrivacySuppressed          PrivacySuppressed
#
#       IND_ENRL_2YR_TRANS_YR3_RT  IND_UNKN_ORIG_YR3_RT  \
# 4275          PrivacySuppressed     PrivacySuppressed
# 3785          PrivacySuppressed     PrivacySuppressed
# 6460                0.023331525     PrivacySuppressed
# 1472          PrivacySuppressed     PrivacySuppressed
# 4586          PrivacySuppressed     PrivacySuppressed
#
#       IND_UNKN_4YR_TRANS_YR3_RT  IND_UNKN_2YR_TRANS_YR3_RT  \
# 4275          PrivacySuppressed          PrivacySuppressed
# 3785          PrivacySuppressed          PrivacySuppressed
# 6460          PrivacySuppressed          PrivacySuppressed
# 1472          PrivacySuppressed          PrivacySuppressed
# 4586          PrivacySuppressed          PrivacySuppressed
#
#       FEMALE_DEATH_YR3_RT          FIRST_GEN
# 4275    PrivacySuppressed        0.520715631
# 3785    PrivacySuppressed  PrivacySuppressed
# 6460    PrivacySuppressed         0.50463353
# 1472    PrivacySuppressed        0.435483871
# 4586    PrivacySuppressed  PrivacySuppressed
#
# [5 rows x 703 columns]

# %%
institutionname = charts['INSTNM']
city= charts['CITY']
state = charts['STABBR']
website= charts['INSTURL']
lat = charts['LATITUDE']
long = charts['LONGITUDE']
adrate = charts['ADM_RATE']
sat = charts['SAT_AVG']
undergrad = charts['UGDS']
tuitionin = charts['TUITIONFEE_IN']
tuitionout= charts['TUITIONFEE_OUT']
firstg = charts['FIRST_GEN']

# %%
collegeinfo = pd.DataFrame({'College_Name':institutionname, 'City':city, 'State' : state, 
                           'Website':website, 'Admission_Rate':adrate, 'Average_SAT':sat, 'Total_Undergraduate':undergrad,
                          'In_State_Tuition':tuitionin,'Out_State_tuition':tuitionout,'First_Generation_Rate':firstg})
collegeinfo
# Out:
#                                            College_Name              City  \
# 0                              Alabama A & M University            Normal
# 1                   University of Alabama at Birmingham        Birmingham
# 2                                    Amridge University        Montgomery
# 3                   University of Alabama in Huntsville        Huntsville
# 4                              Alabama State University        Montgomery
# ...                                                 ...               ...
# 7107                   Arizona State University at Yuma              Yuma
# 7108  Bay Area Medical Academy - San Jose Satellite ...          San Jose
# 7109                        High Desert Medical College         Lancaster
# 7110                                       BCI - Malden            Malden
# 7111          Health Career Institute- Lauderdale Lakes  Lauderdale Lakes
#
#      State                    Website  Admission_Rate  Average_SAT  \
# 0       AL              www.aamu.edu/          0.9027        929.0
# 1       AL                www.uab.edu          0.9181       1195.0
# 2       AL  www.amridgeuniversity.edu             NaN          NaN
# 3       AL                www.uah.edu          0.8123       1322.0
# 4       AL              www.alasu.edu          0.9787        935.0
# ...    ...                        ...             ...          ...
# 7107    AZ               www.asu.edu/             NaN          NaN
# 7108    CA            www.bamasf.com/             NaN          NaN
# 7109    CA               www.hdmc.edu             NaN          NaN
# 7110    MA           bostoncareer.org             NaN          NaN
# 7111    FL               www.hci.edu/             NaN          NaN
#
#       Total_Undergraduate  In_State_Tuition  Out_State_tuition  \
# 0                  4824.0            9857.0            18236.0
# 1                 12866.0            8328.0            19032.0
# 2                   322.0            6900.0             6900.0
# 3                  6917.0           10280.0            21480.0
# 4                  4189.0           11068.0            19396.0
# ...                   ...               ...                ...
# 7107                  NaN               NaN                NaN
# 7108                  NaN               NaN                NaN
# 7109                  NaN               NaN                NaN
# 7110                  NaN               NaN                NaN
# 7111                  NaN           22575.0                NaN
#
#      First_Generation_Rate
# 0              0.365828092
# 1              0.341223671
# 2                   0.5125
# 3              0.310132159
# 4              0.343434343
# ...                    ...
# 7107                   NaN
# 7108           0.519774011
# 7109           0.599640934
# 7110           0.683544304
# 7111                   NaN
#
# [7112 rows x 10 columns]

# %%
from IPython.display import display
while True:
    collegelist=[]
    search = (input('Type the name of the college you are interested:'))
    if search == 'quit':
        break
    else:
        info = collegeinfo[collegeinfo['College_Name']==search]
        collegelist=collegelist.insert(0,info)
        df=pd.concat(collegelist)
        display(df)
# Out:
# Type the name of the college you are interested:Syracuse University
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-83f25c65fe16> in <module>
#       8         info = collegeinfo[collegeinfo['College_Name']==search]
#       9         collegelist=collegelist.insert(0,info)
# ---> 10         df=pd.concat(collegelist)
#      11         display(df)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     253         verify_integrity=verify_integrity,
#     254         copy=copy,
# --> 255         sort=sort,
#     256     )
#     257
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     299             objs = [objs[k] for k in keys]
#     300         else:
# --> 301             objs = list(objs)
#     302
#     303         if len(objs) == 0:
#
# TypeError: 'NoneType' object is not iterable

# %%
collegelist
# Out:
# Empty DataFrame
# Columns: [College_Name, City, State, Website, Admission_Rate, Average_SAT, Total_Undergraduate, In_State_Tuition, Out_State_tuition, First_Generation_Rate]
# Index: []

# %%
info = collegeinfo[collegeinfo['College_Name']==['Harvard University','Syracuse University']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-5aa085da4013> in <module>
# ----> 1 info = collegeinfo[collegeinfo['College_Name']==['Harvard University','Syracuse University']]
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(self, other, axis)
#    1205             # as it will broadcast
#    1206             if other.ndim != 0 and len(self) != len(other):
# -> 1207                 raise ValueError("Lengths must match to compare")
#    1208
#    1209             res_values = na_op(self.values, np.asarray(other))
#
# ValueError: Lengths must match to compare

# %%
d1= collegeinfo[collegeinfo['College_Name']=='Syracuse University']
d1
# Out:
#              College_Name      City State                   Website  \
# 2435  Syracuse University  Syracuse    NY  https://www.syracuse.edu
#
#       Admission_Rate  Average_SAT  Total_Undergraduate  In_State_Tuition  \
# 2435          0.4688       1277.0              14788.0           46755.0
#
#       Out_State_tuition First_Generation_Rate
# 2435            46755.0           0.188679245

# %%
d2= collegeinfo[collegeinfo['College_Name']=='Harvard University']
d2
# Out:
#             College_Name       City State          Website  Admission_Rate  \
# 1557  Harvard University  Cambridge    MA  www.harvard.edu          0.0516
#
#       Average_SAT  Total_Undergraduate  In_State_Tuition  Out_State_tuition  \
# 1557       1523.0               7532.0           48949.0            48949.0
#
#      First_Generation_Rate
# 1557            0.25708061

# %%
frames=[d1,d2]
result=pd.concat(frames)
result
# Out:
#              College_Name       City State                   Website  \
# 2435  Syracuse University   Syracuse    NY  https://www.syracuse.edu
# 1557   Harvard University  Cambridge    MA           www.harvard.edu
#
#       Admission_Rate  Average_SAT  Total_Undergraduate  In_State_Tuition  \
# 2435          0.4688       1277.0              14788.0           46755.0
# 1557          0.0516       1523.0               7532.0           48949.0
#
#       Out_State_tuition First_Generation_Rate
# 2435            46755.0           0.188679245
# 1557            48949.0            0.25708061

# %%
d3=collegeinfo[collegeinfo['College_Name']=='Boston University']
d3
# Out:
#            College_Name    City State     Website  Admission_Rate  \
# 1527  Boston University  Boston    MA  www.bu.edu          0.2511
#
#       Average_SAT  Total_Undergraduate  In_State_Tuition  Out_State_tuition  \
# 1527       1401.0              16716.0           52082.0            52082.0
#
#      First_Generation_Rate
# 1527           0.169382716

# %%
frames.insert(0,d3)
frames
# Out:
# [           College_Name    City State     Website  Admission_Rate  \
#  1527  Boston University  Boston    MA  www.bu.edu          0.2511
#
#        Average_SAT  Total_Undergraduate  In_State_Tuition  Out_State_tuition  \
#  1527       1401.0              16716.0           52082.0            52082.0
#
#       First_Generation_Rate
#  1527           0.169382716  ,
#               College_Name      City State                   Website  \
#  2435  Syracuse University  Syracuse    NY  https://www.syracuse.edu
#
#        Admission_Rate  Average_SAT  Total_Undergraduate  In_State_Tuition  \
#  2435          0.4688       1277.0              14788.0           46755.0
#
#        Out_State_tuition First_Generation_Rate
#  2435            46755.0           0.188679245  ,
#              College_Name       City State          Website  Admission_Rate  \
#  1557  Harvard University  Cambridge    MA  www.harvard.edu          0.0516
#
#        Average_SAT  Total_Undergraduate  In_State_Tuition  Out_State_tuition  \
#  1557       1523.0               7532.0           48949.0            48949.0
#
#       First_Generation_Rate
#  1557            0.25708061  ]

# %%
result
